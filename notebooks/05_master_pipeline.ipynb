# %%
print("Starting bronze ingestion")
# %run ./01_bronze_ingestion.py
print("Finished bronze ingestion")

# %%
print("Starting silver transformation")
# %run ./02_silver_transformation
print("Finished silver transformation")

# %%
print("Starting gold transformation")
#%run ./03_gold_aggregation
print("Finished gold transformation")

# %%
print("Starting data quality")
#%run ./04_data_quality_checks
print("Finished data quality")
